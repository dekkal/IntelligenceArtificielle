# %%
import numpy as np
import pandas as pd

# %%
tab1=np.loadtxt("graphe.txt")
print(tab1)
# Out:
# [3.5304 2.2577 1.9675 1.8404 1.765  1.7112 1.6708 1.6412 1.6167 1.5971]

# %%
Epoch=np.array(["Epoch 1","Epoch 2","Epoch 3","Epoch 4","Epoch 5","Epoch 6","Epoch 7","Epoch 8","Epoch 9","Epoch 10"])

Temps=np.array(["0.13","15.67","23.50","31.33","39.24","47.13","55.01",
                "62.90","70.76","78.59"])

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
x =Temps
y=tab1
plt.plot(x, y, markersize=8)  
plt.xlabel('Temps(mn)')
plt.ylabel('Loss')
plt.title('Evolution de Loss')  
plt.show()

# %%
Précision=np.array(["37.29%","53.12%","55.83%","57.22%","58.15%","58.96%","59.51%","60.06%","60.38%","60.94%"])

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
x =Temps
y=Précision
plt.plot(x, y)  
plt.xlabel('Temps')
plt.ylabel('précision')
plt.title('Evolution de précision')  
plt.show()

# %%
import numpy as np
sum=np.array([470,469.8300452232361,469.55188941955566,469.8209722042084,474.339727640152,473.5302736759186,472.8356602191925,
              473.70689034461975,471.2115454673767,470.0765748023987
              ]).sum()
sum=print(float(sum)/60)
# Out:
# 78.59276440938314

# %%
940.492330789566/60
# Out:
# 15.674872179826101

# %%
7.844371426105499/60
# Out:
# 0.130739523768425
